# %%
df = pd.read_csv(r'C:\Users\Denis\Downloads\output-onlinexmltools.txt', sep = '\t', encoding = 'utf-8')

# %%
df['_TagBased'] = df['_Class']
df['_Class'] = df['_Date']
df['_Date'] = df['_Name']
df['_Name'] = df['_UserId']
df['_UserId'] = df['_Id']
df['_Id'] = df.index

# %%
df
# Out:
#          _Id  _UserId           _Name                    _Date  _Class  \
# 1          1        4        Informed  2016-08-02T15:38:29.913       3
# 2          2        9        Informed  2016-08-02T15:39:20.227       3
# 3          3       16        Informed  2016-08-02T15:39:28.290       3
# 4          4       18        Informed  2016-08-02T15:39:40.377       3
# 5          5       10        Informed  2016-08-02T15:39:56.643       3
# ...      ...      ...             ...                      ...     ...
# 56956  56956    61257  Autobiographer  2022-09-24T18:07:40.790       3
# 56957  56957    61260       Supporter  2022-09-24T18:48:50.723       3
# 56958  56958    61269        Informed  2022-09-25T02:19:46.900       3
# 56959  56959    49023       Supporter  2022-09-25T02:35:30.343       3
# 56960  56960    61270          Editor  2022-09-25T02:41:35.300       3
#
#        _TagBased
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# ...

# %%
df.to_csv(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\badges.csv', index = False, sep='\t')

# %%
df = pd.read_excel(r'C:\Users\Denis\Downloads\Comments.xlsx', engine = 'openpyxl')

# %%
df
# Out:
#          _Id  _PostId  _Score  \
# 0          9       22       1
# 1         10       15       6
# 2         11       22       0
# 3         14       41       1
# 4         24       45       0
# ...      ...      ...     ...
# 23380  56124    37175       0
# 23381  56125    37157       0
# 23382  56126    23377       0
# 23383  56128    37172       0
# 23384  56129    37176       0
#
#                                                    _Text  \
# 0      I think the AI Box is actually a bad introduct...
# 1      Definitely requires a statistical approach wit...
# 2      Fair enough.  I just happen to be more familia...
# 3      If by IQ you mean pattern-finding (which is ge...
# 4      Regarding Asimov's laws, AFAIK, [the zeroth la...
# ...                                                  ...
# 23380  @VladimirZolotov, I don't know of a reference ...
# 23381  Thanks for information. I also wonder if your ...
# 23382  I don't think anybody will try your code befor...
# ...

# %%
df.to_csv(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\Comments.csv', index = False, sep = '\t')

# %%
df = pd.read_csv(r'C:\Users\Denis\Downloads\output-onlinexmltools (1).txt', index_col=None, sep = '\t', encoding = 'utf-8')

# %%
df
# Out:
#                                   _Id  _TagName     _Count _ExcerptPostId  \
# 2                      generalization        35      17536          17535
# 4                             neurons        25       6022           6021
# 8                   intelligent-agent        65       1765           1764
# 9                          philosophy       179       2551           2550
# 12                        fuzzy-logic        24        252            251
# ...                               ...       ...        ...            ...
# 2671                         episodes         1      35844          35843
# 2672                        ms-pacman         1  undefined      undefined
# 2673  bayesian-reinforcement-learning         2      35981          35980
# 2675    out-of-distribution-detection         1  undefined      undefined
# 2676              energy-based-models         1  undefined      undefined
#
#       _WikiPostId
# 2             NaN
# 4             NaN
# 8             NaN
# ...

# %%
df['_WikiPostId'] = df['_ExcerptPostId']
df['_ExcerptPostId'] = df['_Count']
df['_Count'] = df['_TagName']
df['_TagName'] = df['_Id']
df['_Id'] = df.index

# %%
df
# Out:
#        _Id                         _TagName  _Count _ExcerptPostId _WikiPostId
# 2        2                   generalization      35          17536       17535
# 4        4                          neurons      25           6022        6021
# 8        8                intelligent-agent      65           1765        1764
# 9        9                       philosophy     179           2551        2550
# 12      12                      fuzzy-logic      24            252         251
# ...    ...                              ...     ...            ...         ...
# 2671  2671                         episodes       1          35844       35843
# 2672  2672                        ms-pacman       1      undefined   undefined
# 2673  2673  bayesian-reinforcement-learning       2          35981       35980
# 2675  2675    out-of-distribution-detection       1      undefined   undefined
# 2676  2676              energy-based-models       1      undefined   undefined
#
# [978 rows x 5 columns]

# %%
df.to_csv(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\Tags.csv', index = False, sep = '\t')

# %%
df = pd.read_csv(r'C:\Users\Denis\Downloads\PostLinks.csv', index_col=None, sep = ',', encoding = 'utf-8')

# %%
df
# Out:
#          _Id            _CreationDate  _PostId  _RelatedPostId  _LinkTypeId
# 0        103  2016-08-02T19:22:20.577      118              10            1
# 1        136  2016-08-02T21:18:16.763      140              36            1
# 2        179  2016-08-03T05:15:39.443      179              26            1
# 3        194  2016-08-03T06:20:50.550      148             186            1
# 4        195  2016-08-03T06:37:01.983       37              74            1
# ...      ...                      ...      ...             ...          ...
# 2105  461357  2022-09-06T13:06:13.103    36977           24157            1
# 2106  461358  2022-09-06T13:09:43.917    36975           18425            1
# 2107  461359  2022-09-06T13:09:43.917    36975           28291            1
# 2108  461360  2022-09-06T13:09:43.917    36975           24157            1
# 2109  461888  2022-09-10T17:59:04.687    37058           25178            1
#
# [2110 rows x 5 columns]

# %%
df.to_csv(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\PostLinks.csv', index = False, sep = '\t')

# %%
import xml.etree.ElementTree as Xet
import pandas as pd
import collections
  
cols = ['Id', "PostHistoryTypeId", 'PostId', "RevisionGUID", "CreationDate", "UserId", "Text", "ContentLicense"]
rows = []
  
# Parsing the XML file
xmlparse = Xet.parse(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\PostHistory.xml')
root = xmlparse.getroot()
for i in root:
    rows.append(i.attrib)

df = pd.DataFrame(rows, columns=cols)

# %%
df
# Out:
#            Id PostHistoryTypeId PostId                          RevisionGUID  \
# 0           1                 2      1  acd11026-43b5-4640-a6dd-dfff1749f5b5
# 1           2                 1      1  acd11026-43b5-4640-a6dd-dfff1749f5b5
# 2           3                 3      1  acd11026-43b5-4640-a6dd-dfff1749f5b5
# 3           4                 2      2  21760e2e-0597-45b4-bd0d-87a585d25a5e
# 4           5                 1      2  21760e2e-0597-45b4-bd0d-87a585d25a5e
# ...       ...               ...    ...                                   ...
# 90580  148320                 2  37186  228c5cec-a936-4b52-b4b7-8e640481669a
# 90581  148322                 1  37186  228c5cec-a936-4b52-b4b7-8e640481669a
# 90582  148323                 3  37186  228c5cec-a936-4b52-b4b7-8e640481669a
# 90583  148324                 4  37186  046975ba-7165-44d0-b488-2e80c55b4aaf
# 90584  148325                 5  37186  5af0573f-cf50-4c59-be1d-afed57904614
#
#                   CreationDate UserId  \
# ...

# %%
df.to_csv(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\PostHistory.csv', index = False, sep = '\t')

# %%
import xml.etree.ElementTree as Xet
import pandas as pd
import collections
  
cols = ['Id', "PostTypeId", "AcceptedAnswerId", "CreationDate", "Score", "ViewCount", "Body", 
        "OwnerUserId", 'LastEditorUserId', 'LastEditDate', 'LastActivityDate', 'Title', 'Tags', 'AnswerCount', 
       'CommentCount', 'FavoriteCount', 'ContentLicense']
rows = []
  
# Parsing the XML file
xmlparse = Xet.parse(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\Posts.xml')
root = xmlparse.getroot()
for i in root:
    rows.append(i.attrib)

df = pd.DataFrame(rows, columns=cols)

# %%
df
# Out:
#           Id PostTypeId AcceptedAnswerId             CreationDate Score  \
# 0          1          1                3  2016-08-02T15:39:14.947    10
# 1          2          1                9  2016-08-02T15:40:20.623    14
# 2          3          2              NaN  2016-08-02T15:40:24.820    15
# 3          4          1               12  2016-08-02T15:41:22.020    33
# 4          6          1               20  2016-08-02T15:43:35.460     7
# ...      ...        ...              ...                      ...   ...
# 22467  37182          1              NaN  2022-09-24T11:34:39.800     0
# 22468  37183          2              NaN  2022-09-24T14:22:51.947     0
# 22469  37184          2              NaN  2022-09-24T17:44:16.193     1
# 22470  37185          1              NaN  2022-09-25T02:23:46.747     0
# 22471  37186          1              NaN  2022-09-25T02:38:58.383     0
#
#       ViewCount                                               Body  \
# ...

# %%
df.to_csv(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\Posts.csv', index = False, sep = '\t')

# %%
import xml.etree.ElementTree as Xet
import pandas as pd
import collections
  
cols = ['Id', "Reputation", "CreationDate", "DisplayName", "LastAccessDate", "Location", "AboutMe", 
        "Views", 'UpVotes', 'DownVotes', 'ProfileImageUrl', 'AccountId']
rows = []
  
# Parsing the XML file
xmlparse = Xet.parse(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\Users.xml')
root = xmlparse.getroot()
for i in root:
    rows.append(i.attrib)

df = pd.DataFrame(rows, columns=cols)

# %%
df
# Out:
#           Id Reputation             CreationDate         DisplayName  \
# 0          1        101  2016-08-02T15:36:45.333           Adam Lear
# 1          2        101  2016-08-02T15:36:48.397         Nick Craver
# 2          3        101  2016-08-02T15:38:01.633        Geoff Dalgas
# 3          4       2036  2016-08-02T15:38:21.100  Franck Dernoncourt
# 4          5        429  2016-08-02T15:38:27.643        baranskistad
# ...      ...        ...                      ...                 ...
# 53127  61267          1  2022-09-25T01:27:40.830     Diego Domimguez
# 53128  61268          1  2022-09-25T02:12:52.400         Infomatec's
# 53129  61269          1  2022-09-25T02:14:24.833        Zhang NaiChi
# 53130  61270          1  2022-09-25T02:32:05.010             2 False
# 53131  61271          1  2022-09-25T02:38:42.563        David Fertil
#
#                 LastAccessDate                      Location  \
# 0      2021-12-16T15:21:34.940                  New York, NY
# ...

# %%
df.to_csv(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\Users.csv', index = False, sep = '\t')

# %%
import xml.etree.ElementTree as Xet
import pandas as pd
import collections
  
cols = ['Id', "PostId", "VoteTypeId", "CreationDate"]
rows = []
  
# Parsing the XML file
xmlparse = Xet.parse(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\Votes.xml')
root = xmlparse.getroot()
for i in root:
    rows.append(i.attrib)

df = pd.DataFrame(rows, columns=cols)

# %%
df
# Out:
#            Id PostId VoteTypeId             CreationDate
# 0           1      1          2  2016-08-02T00:00:00.000
# 1           2      1          2  2016-08-02T00:00:00.000
# 2           3      1          2  2016-08-02T00:00:00.000
# 3           4      1          2  2016-08-02T00:00:00.000
# 4           5      1          2  2016-08-02T00:00:00.000
# ...       ...    ...        ...                      ...
# 84525  104656  28245          5  2022-09-24T00:00:00.000
# 84526  104657  26336          2  2022-09-24T00:00:00.000
# 84527  104658  22831          2  2022-09-25T00:00:00.000
# 84528  104659   4489          2  2022-09-25T00:00:00.000
# 84529  104660  37184          2  2022-09-25T00:00:00.000
#
# [84530 rows x 4 columns]

# %%
df.to_csv(r'C:\Users\Denis\Data Science\DataScience\University\Maga\DataBases\Project data\Votes.csv', index = False, sep = '\t')
